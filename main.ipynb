# %% [markdown]
# ## Todo:
# - [ ] Add researcher tools
#     - [ ] Search internet (return list of websites)
#     - [ ] Read webpage (return the text from one of those websites, maybe add a different llm call here to summarize the article so the tokens don't get stuck in the messages input tokens)
# - [ ] Consider which messages actually need to get stored and passed to each new request.  Maybe add a "History" object that contains a brief chat history instead of passing all messages each time?  ie. "User asked for blog about blahblahblah.  Manager asked outliner for outline."

# %%
from enum import Enum
from openai import OpenAI
from pydantic import BaseModel
from dotenv import load_dotenv

load_dotenv()

client = OpenAI()

# %%
# Define the data classes for structured output
class ManagerRouter(str, Enum):
    END = "End"
    OUTLINER = "Outliner"
    WRITER = "Writer"

class EmployeeRouter(str, Enum):
    MANAGER = "Manager"

class ManagerResponse(BaseModel):
    response: str
    route: ManagerRouter

class EmployeeResponse(BaseModel):
    response: str
    route: EmployeeRouter

# %%
# Define the system prompts for our various agents
manager_system_prompt = """You work for the world's best tech blog as the manager and editor of the content development team.  You have two employees - an outliner and a writer.  The outliner is responsible for researching and outlining the content, while the writer is responsible for writing the final blog post based on the outline.  The user will ask you to produce a blog on some topic.  

To do so, follow the steps below:

1.  Ask the outliner to research and outline the content.
2.  Review the outline.  If it needs to be adjusted, provide feedback to the outliner.
3.  Once the outline is acceptable, send it to the writer to write the final blog post.
4.  Review the final blog post.  If it needs to be adjusted, provide feedback to the writer.
5.  Once the final blog post is acceptable, send it to the user.

The "route" portion of your response determines who your message will get sent to.  If the route is OUTLINER, direct your response to the outliner employee.  If the route is WRITER, direct your response to the writer employee.  The route END will end the conversation, sending your final response to the user - your final response should be the final blog content in markdown format.
"""

outliner_system_prompt = """You work for the world's best tech blog as a researcher and outliner on the content development team.  You are responsible for researching and outlining the content for the blog post.  Your manager will ask you to research and outline a blog post on some topic.  You should return a concise, bulleted outline of the blog post to your manager.  If the manager provides feedback, make the suggested changes and return the updated outline to the manager."""

writer_system_prompt = """You work for the world's best tech blog as a writer on the content development team.  You are responsible for writing an informative and entertaining blog post based on the provided outline.  Your manager will provide an outline on some topic, and you should turn it into a well-written blog post in markdown format.  If the manager provides feedback, make the suggested changes and return the updated blog post to the manager."""

sysprompts = {
    "Manager": manager_system_prompt,
    "Outliner": outliner_system_prompt,
    "Writer": writer_system_prompt,
}

# %%
# Define the model calling function
def call_model_as_role(role: str, messages: list, sysprompts: dict, client):
    messages = [
        {"role": "system", "content": sysprompts[role]},
    ] + messages[1:]
    response_format = ManagerResponse if role == "Manager" else EmployeeResponse
    raw_response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=messages,
        response_format=response_format,
    )
    r = raw_response.choices[0].message.parsed

    messages.append(
        {
            "role": "assistant",
            "content": f"FROM: {role}\n\nTO:  {r.route.value}\n\n{r.response}"
        }
    )
    return r, messages

# %%
def generate_blog_post(user_topic: str, client, sysprompts, max_calls=10):
    messages = [
        {"role": "user", 
         "content": f"Write a blog post on {user_topic}"},
    ]

    print("Manager thinking...")
    raw_response = client.beta.chat.completions.parse(
        model="gpt-4o",
        messages=messages,
        response_format=ManagerResponse,
    )

    r = raw_response.choices[0].message.parsed

    messages.append(
        {
            "role": "assistant",
            "content": f"FROM: Manager\n\nTO:  {r.route.value}\n\n{r.response}"
        }
    )
    calls = 1

    while True:
        if calls >= max_calls:
            print("Max calls reached.")
            break
        match r.route.value:
            case "Manager":
                print("Manager thinking...")
                r, messages = call_model_as_role(
                    "Manager", messages, sysprompts, client
                )
                calls += 1
            case "Outliner":
                print("Outliner thinking...")
                r, messages = call_model_as_role(
                    "Outliner", messages, sysprompts, client
                )
                calls += 1
            case "Writer":
                print("Writer thinking...")
                r, messages = call_model_as_role(
                    "Writer", messages, sysprompts, client
                )
                calls += 1
            case "End":
                return r, messages
            case _:
                print(f"Error: Invalid route {r.route.value} requested.")
                break

# %%
resp, msgs = generate_blog_post("The impact of AI on modern technology", client, sysprompts)
print(f"Final blog post:\n{'*'*50}\n\n{resp.response}")
# Out:
# Manager thinking...
# Writer thinking...
# Manager thinking...
# Final blog post:
# **************************************************
#
# # The Impact of AI on Modern Technology: Shaping Tomorrow, Today
#
# Artificial Intelligence (AI), once the stuff of science fiction, has become an integral part of modern technology, revolutionizing how we interact with the world around us. It is reshaping industries, enhancing efficiency, and propelling innovation forward at an unprecedented pace. From self-driving cars to intelligent virtual assistants, AI is the driver of a new era where possibilities are limited only by our imagination.
#
# ### 1. Transforming Industries
#
# AI is making waves across various sectors, streamlining operations and enhancing productivity:
#
# - **Healthcare**: AI-powered systems assist doctors by analyzing large datasets to predict patient outcomes, personalize treatments, and even discover potential drug interactions. Robotics equipped with AI algorithms also perform intricate surgeries with higher precision.
#
# - **Finance**: Financial institutions leverage AI for processes like algorithmic trading, fraud detection, and risk management. These systems can analyze vast amounts of data at lightning speed, providing valuable insights and increasing security.
#
# - **Manufacturing**: Smart factories use AI to monitor and optimize production processes, predict equipment failures, and reduce downtime. This leads to cost efficiency and enhanced product quality.
#
# ### 2. Enhancing User Experience
#
# AI’s role in improving user experiences is undeniable:
#
# - **Virtual Assistants**: AI-driven virtual assistants like Siri, Alexa, and Google Assistant have made voice commands a staple in homes, allowing users to manage tasks, control smart devices, and retrieve information hands-free.
#
# - **Personalization**: From streaming services to online shopping platforms, AI algorithms analyze user behavior to offer personalized recommendations, making interactions more engaging and relevant.
#
# - **Customer Support**: Chatbots and AI-driven customer service platforms provide instantaneous responses, addressing user queries with speed and accuracy, enhancing customer satisfaction.
#
# ### 3. Driving Innovation
#
# The infusion of AI in technology fuels groundbreaking innovations:
#
# - **Autonomous Vehicles**: AI is at the heart of self-driving technology. Vehicles equipped with AI can process data from sensors and make real-time decisions, promising enhanced safety and reduced traffic congestion.
#
# - **Smart Cities**: AI powers urban management systems, optimizing traffic flow, energy distribution, and waste management, paving the way for sustainable living.
#
# - **Research and Development**: AI accelerates research by analyzing complex datasets and providing insights that were previously unattainable, fostering scientific discoveries across various fields.
#
# ### 4. Challenges and Considerations
#
# While AI offers numerous benefits, it also poses challenges that need addressing:
#
# - **Ethical Concerns**: The implementation of AI raises questions about data privacy, surveillance, and decision-making biases, necessitating robust ethical guidelines.
#
# - **Job Displacement**: As AI automates more tasks, there's a potential for job displacement. It's essential to focus on reskilling and upskilling the workforce to adapt to new AI-driven roles.
#
# ### 5. The Road Ahead
#
# AI continues to be a pivotal force in the advancement of modern technology, and its impact is only expected to grow. Its integration across different domains not only improves existing systems but also paves the way for the development of entirely new technologies. For innovators, policymakers, and society as a whole, the ongoing journey with AI will be about harnessing its enormous potential responsibly to build a future where technology and humanity coexist in harmony.
#
# In conclusion, AI is rewriting the rules of technology, and as we stand on the brink of its full potential, the possibilities are as vast as they are thrilling. Embracing AI thoughtfully and strategically will determine how we navigate the technological landscapes of tomorrow.

# %% [markdown]
# ## Scratch code for internet search

# %%
# !pip install beautifulsoup4 google
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/jakebraun/repos/.venv/lib/python3.11/site-packages (4.12.3)
# Collecting google
#   Obtaining dependency information for google from https://files.pythonhosted.org/packages/ac/35/17c9141c4ae21e9a29a43acdfd848e3e468a810517f862cad07977bf8fe9/google-3.0.0-py2.py3-none-any.whl.metadata
#   Downloading google-3.0.0-py2.py3-none-any.whl.metadata (627 bytes)
# Requirement already satisfied: soupsieve>1.2 in /Users/jakebraun/repos/.venv/lib/python3.11/site-packages (from beautifulsoup4) (2.6)
# Downloading google-3.0.0-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 845.9 kB/s eta 0:00:00 kB/s eta 0:00:01
# Installing collected packages: google
# Successfully installed google-3.0.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from googlesearch import search

query = "Coffee"

result = search(query, num=10, stop=10, pause=2)

# %%
results = [r for r in result]

# %%
results
# Out:
# ['https://en.wikipedia.org/wiki/Coffee',
#  'https://en.wikipedia.org/wiki/History_of_coffee',
#  'https://en.wikipedia.org/wiki/Coffee_bean',
#  'https://en.wikipedia.org/wiki/Coffee_preparation',
#  'https://en.wikipedia.org/wiki/Coffee_production',
#  'https://www.peets.com/',
#  'https://www.peets.com/collections/all-coffees',
#  'https://www.peets.com/pages/store-locator',
#  'https://www.peets.com/pages/menu',
#  'https://www.peets.com/pages/coffeepeople']

# %%
import urllib.request

page = urllib.request.urlopen(results[0])
print(page.read())
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Coffee - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",\n"wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"4ba7d1ae-f85e-463b-8c2f-cb5de5b21311","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Coffee","wgTitle":"Coffee","wgCurRevisionId":1270329163,"wgRevisionId":1270329163,"wgArticleId":604727,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Latin-language sources (la)","CS1 maint: location missing publisher","CS1 French-language sources (fr)","All articles with dead external links","Articles with dead external links from October 2023","Articles with permanently dead external links","CS1 Italian-language sources (it)","CS1 maint: postscript","Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely move-protected pages","Wikipedia indefinitely semi-protected pages",\n"Use American English from September 2022","All Wikipedia articles written in American English","Use dmy dates from September 2022","Articles with hRecipes","Articles with hProducts","Articles containing Dutch-language text","Articles containing Ottoman Turkish (1500-1928)-language text","Articles containing Arabic-language text","Articles with text in Cushitic languages","Articles with text in Semitic languages","Articles containing Hebrew-language text","Articles containing Latin-language text","Articles containing German-language text","Pages using multiple image with auto scaled images","Articles containing Greek-language text","Articles containing Turkish-language text","CS1: long volume value","Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference","Commons category link from Wikidata","Coffee","Crops","Drinks","Herbal and fungal stimulants","Hot drinks","Non-alcoholic drinks","Yemeni beverages"],"wgPageViewLanguage":"en",\n"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Coffee","wgRelevantArticleId":604727,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["sysop"],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"statu ...

# %%
# https://stackoverflow.com/questions/328356/extracting-text-from-html-file-using-python
from bs4 import BeautifulSoup
url = results[5]
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

for script in soup(["script", "style"]):
    script.extract()

text = soup.get_text()

lines = (line.strip() for line in text.splitlines())
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
text = '\n'.join(chunk for chunk in chunks if chunk)
print(text)
# Out:
# Peet's Coffee | The Original Craft Coffee, Est. 1966
# Click to view our Accessibility Statement
# Skip to content
# Skip to navigation
# Prev Promo
# Free Shipping on orders $49+
# Shop Now
# Next Promo
# Prev Promo
# Subscribers get Free Shipping & up to 10% Off
# Subscribe Now
# Next Promo
# Peet’s coffee graphic logo
# Free Shipping
# Coffee
# Shop
# About Us
# Our Stores
# Log in
# Search
# Search
# My Account
# Store Locator
# Toggle Cart
# Toggle Menu
# Close Search
# Search
# Search
# Popular Searches
# Dark Roast Coffee
# Decaf Coffee
# Espresso Capsules
# Featured
# Gift Subscription
# The Bright Collection
# Subscribe & Save
# Best Sellers
# Exclusives
# Decaf Coffee
# Shop All Coffee
# Roast
# Dark Roast
# Medium Roast
# Light Roast
# Brew Format
# Coffee Beans
# K-Cup® Pods
# Espresso Capsules
# Cold Brew
# Ultra Coffee Concentrate
# Shop Now
# Shop
# Subscribe & Save
# Coffee
# Offers
# Tea
# E-Gift Cards
# Mugs + Gear
# Shop Now
# About Us
# Coffee for Coffee People
# Sourcing with Impact
# Recipes + Blog
# Why Peet's?
# Brew Guides
# Peet's History
# Discover. Sip. Savor.
# Discover. Sip. Savor.
# Our Stores
# Find a Peet's Coffeebar
# Get the Peet's App
# Find Peet's at a Grocery Store
# Find a Coffeebar
# Find a Coffeebar
# Toggle menu
# Free Shipping
# Coffee
# Featured
# Gift Subscription
# The Bright Collection
# Subscribe & Save
# Best Sellers
# Exclusives
# Decaf Coffee
# Shop All Coffee
# Roast
# Dark Roast
# Medium Roast
# Light Roast
# Brew Format
# Coffee Beans
# K-Cup® Pods
# Espresso Capsules
# Cold Brew
# Ultra Coffee Concentrate
# Shop Now
# Shop
# Subscribe & Save
# Coffee
# Offers
# Tea
# E-Gift Cards
# Mugs + Gear
# Shop Now
# About Us
# Coffee for Coffee People
# Sourcing with Impact
# Recipes + Blog
# Why Peet's?
# Brew Guides
# Peet's History
# Discover. Sip. Savor.
# Discover. Sip. Savor.
# Our Stores
# Find a Peet's Coffeebar
# Get the Peet's App
# Find Peet's at a Grocery Store
# Find a Coffeebar
# Find a Coffeebar
# WELCOME TO ANOTHER DIMENSION
# With its notes of wild blueberries, white flower, and candied peel, tasting is believing. Experience the out-of-this-world flavors of our limited release Ethiopian Super Natural.
# SHOP NOW
# SHOP ALL COFFEE
# WELCOME TO ANOTHER DIMENSION
# With its notes of wild blueberries, white flower, and candied peel, tasting is believing. Experience the out-of-this-world flavors of our limited release Ethiopian Super Natural.
# SHOP NOW
# SHOP ALL COFFEE
# RISE & THRIVE
# We’re greeting the new year with energetic optimism, beginning with our new Vitality Menu. Lattes with 20g or more of protein in a medium size, and sparkling immunity drinks with a high content of Vitamins C & D to help support a healthy immune system. Refuel. Revive. Enjoy.
# ORDER NOW
# YOUR NEW MORNING ROUTINE

# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Italian Roast
# Starting at $18.95
# Italian Roast
# Starting at $18.95
# For those seeking a penetrating, balanced roast with vigorous flavors. Masterfully slow roasted for boldly perfect cups.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaf Major Dickason's Blend®
# Starting at $19.95
# Decaf Major Dickason's Blend®
# Starting at $19.95
# Quite possibly the most flavorful cup of decaf you’ll ever taste. Our most popular blend, without caffeine.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaf Mocca-Java
# Starting at $20.95
# Decaf Mocca-Java
# Starting at $20.95
# Water-process decaffeination means you’ll taste only the rich, ancient blend of Java and Ethiopian Mocca coffees, not caffeine.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Holiday Blend
# Starting at $22.95
# Holiday Blend
# Starting at $22.95
# A rich blend of layered origins, threading the warmth of the season through classic interplays of brown sugar & black currant with notes of warm spice and a lingering finish.
# Last order date: January 5
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Aged Sumatra
# Starting at $19.95
# Aged Sumatra
# Starting at $19.95
# Concentrated body and distinctly nuanced aroma transport the senses in this rich and complex “spice box of flavors.”
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# House Blend
# Starting at $17.95
# House Blend
# Starting at $17.95
# You know when something is a favorite, there’s a reason. Let this Latin American blend be your perfect introduction to Peet’s coffees.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Yosemite Dos Sierras Organic
# Starting at $20.95
# Yosemite Dos Sierras Organic
# Starting at $20.95
# Feel the connection to the canopied mountains where this sustainable, Bird Friendly certified Colombian coffee is grown. Complex and satisfying with milk chocolate sweetness.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Sulawesi-Kalosi
# Starting at $19.95
# Sulawesi-Kalosi
# Starting at $19.95
# Taste heaven in your cup. A rare coffee, semi-aged and cultivated in the traditional Sulawesi method.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Café Domingo®
# Starting at $18.95
# Café Domingo®
# Starting at $18.95
# Looking for some slow sipping and savoring? This medium roast blend was crafted from three Latin American coffees, for moments just like these.
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Big Bang™
# Starting at $18.95
# Big Bang™
# Starting at $18.95
# Our most loved medium roast—smooth with a balanced richness.
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Guatemala San Sebastián
# Starting at $20.95
# Guatemala San Sebastián
# Starting at $20.95
# Savor a coffee both potent and refined from the best farm in Antigua, a favorite of our Roastmasters for more than 40 years.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Garuda Blend®
# Starting at $18.95
# Garuda Blend®
# Starting at $18.95
# Celebrate the diverse flavors of the islands with this satisfying blend of tropical single-origin Indo-Pacific coffees.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaf French Roast
# Starting at $19.95
# Decaf French Roast
# Starting at $19.95
# For those who enjoy the bold taste and smoky overtones of French Roast but prefer to do without the caffeine.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Arabian Mocha Sanani
# Starting at $27.95
# Arabian Mocha Sanani
# Starting at $27.95
# For those who embrace a bit of wildness, a full-bodied desert miracle from Yemen’s harsh, dry mountain terrain.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Sumatra
# Starting at $19.95
# Sumatra
# Starting at $19.95
# A sensory, seductive cup, brimming with complexity and herbal nuance. Rustically hand-processed for those seeking classic Indonesian heft.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Organic French Roast
# Starting at $20.95
# Organic French Roast
# Starting at $20.95
# To brew French Roast is a commitment to the enjoyment of rich, powerful taste, pronounced smoky overtones, and pleasant bite.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaf Sumatra
# Starting at $20.95
# Decaf Sumatra
# Starting at $20.95
# With the same richness and character as our regular Sumatra, it’s hard to imagine this is a decaf coffee.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Kenya Auction Lot
# Starting at $20.95
# Kenya Auction Lot
# Starting at $20.95
# Many say Kenyan coffee is the best there is; we don't think there's any better than our Auction Lot— juicy, complex, sweet, and dazzling.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Ethiopian Fancy
# Starting at $19.95
# Ethiopian Fancy
# Starting at $19.95
# Experience the elegance of Ethiopia, the birthplace of coffee, with this aromatic coffee, meticulously prepared by the washed method.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Colombia
# Starting at $17.95
# Colombia
# Starting at $17.95
# For those seeking exceptional, full-bodied Colombian coffee, shining and sweet from the rarest lots.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Single Origin Series
# Starting at $19.95
# Single Origin Series
# Starting at $19.95
# Our single origin coffees are the quintessential expressions of a coffee’s terroir. Explore the unique, nuanced flavors of the world’s best coffee regions month by month, getting to know the elemental flavors and aromatics specific to each region.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Major Dickason's Blend® K-Cup® Pods
# Starting at $9.99
# Major Dickason's Blend® K-Cup® Pods
# Starting at $9.99
# Refine your palate and elevate your coffee experience with this premier blend, our all-time best seller.
# *Sold in increments of 3 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Ristretto Espresso Capsules
# Starting at $10.00
# Ristretto Espresso Capsules
# Starting at $10.00
# Ristretto (intensity 10, dark roast) evokes a classic “short pull” espresso, with notes of crushed spiced and rich chocolate. Compatible with Nespresso Original machines.*
# *Sold in increments of 5 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Nerissimo Espresso Capsules
# Starting at $10.00
# Nerissimo Espresso Capsules
# Starting at $10.00
# Black as night, sweet as a brûlée topping. Nerissimo (intensity 11) is our darkest espresso roast in a convenient aluminum capsule that is compatible with your Nespresso Original machine.*
# *Sold in increments of 5 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Crema Scura Espresso Capsules
# Starting at $10.00
# Crema Scura Espresso Capsules
# Starting at $10.00
# Crema Scura (intensity 9, medium roast) offers a dark luscious crema and earthy, nutty notes in a convenient aluminum capsule that is compatible with your Nespresso Original machine.*
# *Sold in increments of 5 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Ethiopian Super Natural Organic
# Starting at $22.95
# Ethiopian Super Natural Organic
# Starting at $22.95
# Wildly fragrant and famous for its unequalled natural flavor: a distinctive blast of dried blueberries shot through with notes of white flower, finishing with candied citron sweetness.
# Last day to order: February 28
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# Espresso
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# French Roast K-Cup® Pods
# Starting at $9.99
# French Roast K-Cup® Pods
# Starting at $9.99
# For those who relish smoky overtones and a pleasant bite, drinking French Roast exemplifies our commitment to rich, powerful coffee.
# *Sold in increments of 3 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaffeinato Ristretto Espresso Capsules
# Starting at $10.00
# Decaffeinato Ristretto Espresso Capsules
# Starting at $10.00
# Decaffeinato Ristretto (intensity 9, dark roast) is fragrant and nutty with a luxurious finish. It's rich, bold decaf espresso in a convenient aluminum capsule that's compatible with your Nespresso Original machine.*
# *Sold in increments of 5 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaf Holiday Blend
# Starting at $22.95
# Decaf Holiday Blend
# Starting at $22.95
# A rich blend of layered origins, threading the warmth of the season through classic interplays of brown sugar & black currant with notes of warm spice and a lingering finish.
# Last order date: January 5
# *Note: The bag will be labeled "Decaf" on the right-hand side panel.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaf House Blend K-Cup® Pods
# Starting at $9.99
# Decaf House Blend K-Cup® Pods
# Starting at $9.99
# Let this customer-favorite Latin American blend be your perfect introduction to Peet’s coffees, without the caffeine. Rich and balanced.
# *Sold in increments of 3 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Seasonal Essentials Series
# Starting at $22.95
# Seasonal Essentials Series
# Starting at $22.95
# These coffees get more than just reviews—they get fan letters. Experience our most anticipated, limited release coffees of each season without having to mark your calendar. Enjoy our Holiday Blend, Anniversary Blend, Ethiopian Super Natural and more!
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# French Press
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Holiday Blend K-Cup® Pods
# Starting at $14.95
# Holiday Blend K-Cup® Pods
# Starting at $14.95
# A rich blend of layered origins, threading the warmth of the season through classic interplays of brown sugar & black currant with notes of warm spice and a lingering finish.
# *Sold in increments of 3 boxes.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Dark Roast Series
# Starting at $19.95
# Dark Roast Series
# Starting at $19.95
# Take a deeper dive into dark roast. Each month subscribers experience a curated selection of classics like Ethiopian Fancy, Sumatra, Major Dickason’s Blend, and French Roast.
# Roast Type :
# Dark Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Medium Roast Series
# Starting at $19.95
# Medium Roast Series
# Starting at $19.95
# Talk about easy-drinking. Experience one of our most-loved medium roasts every month, including flavorful favorites like Big Bang®, Café Domingo®, and Organic Alameda Morning Blend.
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Caramel Espresso Capsules
# Starting at $10.00
# Caramel Espresso Capsules
# Starting at $10.00
# Sweet espresso melds beautifully with rich caramel and the creaminess of steamed milk. Available in a convenient capsule that is compatible with your Nespresso Original machine.*
# *Sold in increments of 5 boxes.
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Decaf Series
# Starting at $20.95
# Decaf Series
# Starting at $20.95
# It’s true, we do decaf better, including flavorful favorites like Decaf Big Bang®, Decaf House Blend, Decaf Major Dickason’s Blend, and Decaf Sumatra.
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Whole Bean
# Drip
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# K-Cup® Pods Series
# Starting at $9.99
# K-Cup® Pods Series
# Starting at $9.99
# For the ultimate in convenience, Peet’s K-Cup® Pods Subscription Series delivers a curated selection of delightful new flavors every month.
# *Sold in increments of 3 boxes
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# K-Cup® Pods Sampler Bundle
# Starting at $59.92
# K-Cup® Pods Sampler Bundle
# Starting at $59.92
# Explore the world of Peet's K-Cup Pods with this variety pack featuring eight 10ct boxes in our bestselling K-Cup flavors.
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# Close
# Espresso Capsules Sampler Bundle
# Starting at $30.00
# Espresso Capsules Sampler Bundle
# Starting at $30.00
# Explore 4 of our dark, rich espresso blends with this variety pack featuring Nerissimo, Ristretto, Crema Scura, & Ricchezza (10ct carton of each). Compatible with your Nespresso Original machine.*
# Roast Type :
# Medium Roast
# Learn More
# 1
# Select Your Grind :
# Default Title
# 2
# Quantity :
# Decrease quantity.
# 1 Bag
# Quantity
# Increase quantity.
# 3
# Frequency :
# Decrease frequency.
# 4 Weeks
# Frequency
# Increase frequency.
# Add Subscription To Cart
# ENJOY FREE HOME DELIVERY, SUBSCRIBE AND SAVE
# 30% OFF FOR NEW SUBSCRIBERS
# Start a new subscription and get 30% off your first order
# FREE SHIPPING
# We cover the cost, so you can enjoy every cup
# NEW COFFEE EACH MONTH
# Our Curated Series subscriptions feature a different coffee each month
# CHOOSE A SUBSCRIPTION
# From the Coffeebar
# A WELL-ROUNDED BREAKFAST
# Your new favorite breakfast has arrived. Grab a Protein Latte with 20g or more of protein in a medium, and pair it with a plant-based breakfast sandwich. Delicious and satisfying.
# Vanilla Protein Latte
# Vanilla Protein Latte
# Order Now
# Matcha Protein Latte
# Matcha Protein Latte
# Order Now
# Golden Protein Latte
# Golden Protein Latte
# Order Now
# Immunity Sparkling Golden Lemonade
# Immunity Sparkling Golden Lemonade
# Order Now
# Immunity Sparkling Citrus Tea
# Immunity Sparkling Citrus Tea
# Order Now
# Iced Vanilla Protein Latte
# Iced Vanilla Protein Latte
# Order Now
# Iced Matcha Protein Latte
# Iced Matcha Protein Latte
# Order Now
# Iced Golden Protein Latte
# Iced Golden Protein Latte
# Order Now
# Sparkling Peppermint Vanilla Cold Brew
# Sparkling Peppermint Vanilla Cold Brew
# Order Now
# The Derby
# The Derby
# Order Now
# The Bestie
# The Bestie
# Order Now
# Sparkling Tiger's Eye
# Sparkling Tiger's Eye
# Order Now
# 1
# / 12
# View All
# Find A CoffeeBar
# OUR COFFEE REVOLUTION
# When Alfred Peet opened the doors to his first coffeebar in 1966, he forever changed the expectations of American coffee drinkers.
# LEARN MORE
# NEVER MISS AN OFFER
# Sign up for our newsletter and receive 10% off + free shipping on your first order.
# Sign Up
# Peet’s Coffee Berkeley, California
# Est. 1966
# Instagram
# Twitter
# Facebook
# Youtube
# LinkedIn
# TikTok
# Help center
# Contact Us
# Help Center
# Shipping & Returns
# Company
# Careers
# Our People
# Newsroom
# Code of Ethics
# Supply Chain Transparency
# Supplier Code of Conduct
# Gift cards
# Shop Gift Cards
# Offers
# Student Discount
# Current Offers
# GET $25
# Partner with peet's
# Foodservice Program
# Become an affiliate
# Franchise
# Find peet's in grocery
# Product Finder
# Blog
# The Cupping Room
# The peet's app
# Peet's App on the Apple Store
# Peet's App on the Google Play Store
# © 2025. PEET'S COFFEE
# |
# Privacy Policy
# |
# Your Privacy Choices
# |
# Terms of Use
# *Nespresso is a registered trademark of Société des Produits Nestlé S.A., and is not affiliated with Peet’s Coffee Inc. Compatible with most Nespresso Original machines.
# Cart
# Close Cart
# You are $49.00 away from free shipping!
# You are $49.00 away from free shipping!
# Get free ground shipping on subscriptions
# Your cart is empty. Do you need any beans or tea?
# Shop Coffee
# Shop Tea
# Shop Equipment
# Shop Subscriptions
# Subtotal
# $0
# Ships on or before
# Toggle ship date message
# Close tooltip
# Estimated ship date based on items in your cart. Ship dates subject to change. Visit our FAQ page to learn more.
# Checkout
# View Cart
# Close
# You Currently Have Items In Your Shopping Cart.
# You Currently Have a Peet's Card In Your Shopping Cart.
# Peet's Cards can be purchased only as a single-item transaction. After completing this order, begin a new transaction to purchase a Peet's Card.
# Peet's Cards can be purchased only as a single-item transaction. After completing this order, begin a new transaction to purchase other desired items.
# View Cart
# Close
# EARTH MONTH 2023
# “The Earth is what we all have in common.”
# Wendell Berry
# Shop Now
# Create Account
# Sign In
# Email
# Password
# Translation missing: en.customer.login.submit
# Cancel
